# %%
#W7A1
def bs(arr, left, right, target):
    while left <= right:
        mid = (left + right) // 2
        if arr[mid] == target:
            return mid
        elif arr[mid] > target:
            right = mid - 1
        else:
            left = mid + 1
    return -1

arr = list(map(int, input().split()))
target = int(input())
left, right = 0, len(arr) - 1
print(bs(arr, left,right, target))
# Out:
# 3

# %%
#W7A2
def count_occurrences(arr, x) -> int:
    dic = dict({})
    for i in arr:
        dic[i] = dic.get(i, 0) + 1
    if x not in set(arr):
        return 0
    return dic[x]

arr = list(map(int, input().split()))
x = int(input())
print(count_occurrences(arr, x))
# Out:
# 3

# %%
#W7A3:
def bubble_sort(arr, n):
    for i in range(n - 1):
        status = False
        for j in range(n - i - 1):
            if arr[j + 1] < arr[j]:
                arr[j + 1], arr[j] = arr[j], arr[j + 1]
                status = True
        if not status :
            break
    return arr


def selection_sort(arr, n):
    for i in range(n - 1):
        min_index = i
        for j in range(i + 1, n):
            if arr[j] < arr[min_index]:
                min_index = j
        arr[i], arr[min_index] = arr[min_index], arr[i]
    return arr

arr = list(map(int, input().split()))
n = len(arr)
print(*bubble_sort(arr,n))
print(*selection_sort(arr, n))
# Out:
# 1 2 2 3 3 4 5 6 7 8
# 1 2 2 3 3 4 5 6 7 8

# %%
#W7A4
ls = list(map(int, input().split()))
dic = dict({})
for i in ls:
    dic[i] = dic.get(i, 0) + 1
for i in ls:
    if dic[i] == max(dic.values()):
        print(i)
        break
# Out:
# 2

# %%
#W7A5
def count_pairs(ls, X):
    cnt = 0
    freq = {}
    for a in ls:
        b = X - a
        if b in freq:
            cnt += freq[b]
        if a in freq:
            freq[a] += 1
        else:
            freq[a] = 1
    return cnt

ls = list(map(int, input().split()))
X = int(input())
print(count_pairs(ls, X))
# Out:
# 14

# %%
#W7A6
def flatten_list(ls):
    return [x for i in ls for x in i]

n = int(input())
ans = []
for _ in range(n):
    a = list(map(int, input().split()))
    ans.append(a)

print(flatten_list(ans))
